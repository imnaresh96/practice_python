# %%
import random
name=input('Enter Your Name: ')
x=input('Press Y For Play: ')
while x=='y':
    num=random.randint(1,6)
    if num==1:
        print('''-----------
                 |         |
                 |         |
                 |    O    |
                 |         |
                 |         |
                 -----------
        ''')
    elif num==2:
        print('''-----------
                 |         |
                 |         |
                 |  O   O  |
                 |         |
                 |         |
                 -----------
        ''')
    elif num==3:
        print('''-----------
                 |    O    |
                 |         |
                 |    O    |
                 |         |
                 |    O    |
                 -----------
        ''')
    elif num==4:
        print('''-----------
                 | O     O |
                 |         |
                 |         |
                 |         |
                 | O     O |
                 -----------
        ''')
    elif num==5:
        print('''-----------
                 | O     O |
                 |         |
                 |    O    |
                 |         |
                 | O     O |
                 -----------
        ''')
    elif num==6:
        print('''-----------
                 | O     O |
                 |         |
                 | O     O |
                 |         |
                 | O     O |
                 -----------
        ''')
    x=input('Press Y For Play Again: ')
