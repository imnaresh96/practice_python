# %%
def status(name,age,mobile):
    if type(name)==str and type(age)==int and type(mobile)==int:
        return f" hello {name}! your age is {age}, for contact to call and text this number {mobile}"
    else:
        return "please confirm your all details and resubmit"

# %%
name=input()
age=int(input())
mobile=int(input())
status(name,age,mobile)
# Out:
# fjf
# 23
# 45464
# ' hello fjf! your age is 23, for contact to call and text this number 45464'

# %%
def multi(x,y,*numbers):
  multi=x*y
  for i in numbers:
    multi=multi*i
  return multi

# %%
multi(4,7)
# Out:
# 28

# %%
multi(8,7,4,5,2,5,1,2)
# Out:
# 22400

# %%
multi(7,4,7)
# Out:
# 196

# %%
multi(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-64aa9d6e5e06> in <module>
# ----> 1 multi(2)
#
# TypeError: multi() missing 1 required positional argument: 'y'

# %%
type(multi)
# Out:
# function

# %%
def multi(x,y,*numbers):
  multi=x*y
  for i in numbers:
    multi=multi*i
  else:
    print(multi)

# %%
multi(4,5,6)
# Out:
# 120

# %%
multi(0,0)
# Out:
# 0

# %%
def multi(*numbers):
  same=1
  for i in numbers:
    same=same*i
  return same

# %%
multi(5,8)
# Out:
# 40

# %%
multi(7)
# Out:
# 7

# %%
s=[5,4,6,9,8,5,4,1,2,3,6,5]

# %%
type(s)
# Out:
# list

# %%
print(dir(s))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
sum(s)
# Out:
# 58

# %%
k=1,5,6,9,8,5,4,5,7

# %%
type(k)
# Out:
# tuple

# %%
sum(k)
# Out:
# 50

# %%
a='hello world'
print(a[::])
# Out:
# hello world

# %%
print(a[2:12])
# Out:
# llo world

# %%
print(a[6:])
# Out:
# world

# %%
my_set = {1, 2, 3, 4}   
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_set.discard(4)
print(my_set)
# Out:
# {1, 2, 3}

# %%
  my_set.remove(4)
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-63607fe6e23f> in <module>
# ----> 1 my_set.remove(4)
#       2 print(my_set)
#
# KeyError: 4

# %%
my_set.pop()
# Out:
# 1

# %%
my_set={2,54,7,5,1,5,3,5}

# %%
my_set
# Out:
# {1, 2, 3, 5, 7, 54}

# %%
my_set.pop()
# Out:
# 1

# %%
print(my_set.pop())
# Out:
# 2

# %%
my_set.pop()
print(my_set)
# Out:
# {5, 7, 54}

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}

# use | operator
print(A | B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
# Frozensets
# initialize A and B
A = frozenset([1, 2, 3, 4])
B = frozenset([3, 4, 5, 6])

# %%
B.difference(A)
# Out:
# frozenset({5, 6})

# %%
fruits =["apple","banana"]
for x in fruits:
    print(x)
# Out:
# apple
# banana

# %%
fruits =["apple","banana"]
for x in fruits:
  if x=='banana':
    print(x)
# Out:
# banana
