# %%
import random
random.random()
# Out:
# 0.03644676857543183

# %%
random.random()
# Out:
# 0.5202430153800842

# %%
random.randrange(1000,9999)
# Out:
# 2804

# %%
random.randrange(100,999)
# Out:
# 637

# %%
random.randrange(1,5)
# Out:
# 4

# %%
random.randrange(1,5)
# Out:
# 1

# %%
random.randrange(1,5)
# Out:
# 4

# %%
random.choice('hello')
# Out:
# 'l'

# %%
random.choice([1,4,5,6,8])
# Out:
# 4

# %%
random.choices([45,4,6,8,5,],k=2)
# Out:
# [6, 8]

# %%
random.choices([45,4,6,8,5,],k=3)
# Out:
# [4, 5, 45]

# %%
random.randint(1,5)
# Out:
# 3

# %%
random.random()*10
# Out:
# 0.2537915160937676

# %%
random.random()*100
# Out:
# 72.60980911533919

# %%
random.random()*2.5
# Out:
# 0.3468337862993784

# %%
random.random()*-100
# Out:
# -91.21506943543316

# %%
random.randrange(-100,1)
# Out:
# -100

# %%
random.randrange(-100,1)
# Out:
# -50

# %%
random.randrange(1,-100,-1)
# Out:
# -90

# %%
az='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()-_=+'

# %%
password=random.choices(az, k=10)
# Out:
# ['_', '#', '%', '@', 'K', '3', 'p', 'O', 'H', 'm']

# %%
''.join(random.choices(az, k=10))
# Out:
# '+aNa(5%n3L'

# %%
user=list()
name=input('enter your name: ')
id =input('enter your id: ')
password=''.join(random.choices(az, k=10))
user.extend([name,id,password])
print(tuple(user))
# Out:
# enter your name: natesh
# enter your id: 526326
# ('natesh', '526326', 'uPCX=60VIk')

# %%
type(user)
# Out:
# list
