# %%
5<2
# Out:
# False

# %%
5>2
# Out:
# True

# %%
import pandas as pd
import pymysql
import datetime

# %%
def create_ip_subnet(ip_list):
#     json_=request.get_json()
#     ip_list=json_['ip_list']
#     customername=json_['customername']
    customername="Sattrix"
    data=pd.DataFrame()
    duplicate_ip=[]
    db = pymysql.connect(host="localhost", user="root", password="Sattrix@123", database="NewEvol")
    for i in ip_list:
        today_date = datetime.datetime.now()
        tdate = today_date.strftime("%d-%m-%Y %H:%M:%S")
        i=i.strip()
        ip_subnet = i.rfind('.')
        slash = i.rfind('/')
        subnet_end = int(i[(slash) + 1:])
        cur=db.cursor()
        query='''select CustomerName from subnetMapping where IP_Subnet='{}' '''.format(i)
        cur.execute(query)
        ip_available=cur.fetchall()
        if not ip_available:
            if subnet_end == 24:
                pattern = '''^{}.(?:[1-9]|[1-9][0-9]|[1][0-9][0-9]|[2][0-4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
                dataframe = [
                    {
                        "Department_Name": "Python",
                        "Modification_Date":tdate,
                        "End_IP": i[:ip_subnet] + '.254',
                        "IP_Subnet": i,
                        "Start_IP": i[:ip_subnet] + '.0',
                        "CustomerName":customername ,
                        "regex": pattern
                    }
                ]
                ip_rows = pd.DataFrame(dataframe)
                data = pd.concat([ip_rows, data], ignore_index=True)
            if subnet_end == 25:
                pattern = '''^{}.(?:12[8-9]|1[3-9][0-9]|2[0-4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
                dataframe = [
                    {
                        "Department_Name": "Python",
                        "Modification_Date": tdate,
                        "End_IP": i[:ip_subnet] + '.254',
                        "IP_Subnet": i,
                        "Start_IP": i[:ip_subnet] + '.128',
                        "CustomerName": customername,
                        "regex": pattern
                    }
                ]
                ip_rows = pd.DataFrame(dataframe)
                data = pd.concat([ip_rows, data], ignore_index=True)
            if subnet_end == 26:
                pattern = '''^{}.(?:19[2-9]|2[0-4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
                dataframe = [
                    {
                        "Department_Name": "Python",
                        "Modification_Date": tdate,
                        "End_IP": i[:ip_subnet] + '.254',
                        "IP_Subnet": i,
                        "Start_IP": i[:ip_subnet] + '.192',
                        "CustomerName": customername,
                        "regex": pattern
                    }
                ]
                ip_rows = pd.DataFrame(dataframe)
                data = pd.concat([ip_rows, data], ignore_index=True)
            if subnet_end == 27:
                pattern = '''^{}.(?:22[4-9]|2[3-4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
                dataframe = [
                    {
                        "Department_Name": "Python",
                        "Modification_Date": tdate,
                        "End_IP": i[:ip_subnet] + '.254',
                        "IP_Subnet": i,
                        "Start_IP": i[:ip_subnet] + '.224',
                        "CustomerName":customername,
                        "regex": pattern
                    }
                ]
                ip_rows = pd.DataFrame(dataframe)
                data = pd.concat([ip_rows, data], ignore_index=True)
            if subnet_end == 28:
                pattern = '''^{}.(?:[2][4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
                dataframe = [
                    {
                        "Department_Name": "Python",
                        "Modification_Date": tdate,
                        "End_IP": i[:ip_subnet] + '.254',
                        "IP_Subnet": i,
                        "Start_IP": i[:ip_subnet] + '.240',
                        "CustomerName": customername,
                        "regex": pattern
                    }
                ]
                ip_rows = pd.DataFrame(dataframe)
                data = pd.concat([ip_rows, data], ignore_index=True)
            if subnet_end == 29:
                pattern = '''^{}.(?:[2][4][8-9]|25[0-4])$'''.format(i[:ip_subnet])
                dataframe = [
                    {
                        "Department_Name": "Python",
                        "Modification_Date": tdate,
                        "End_IP": i[:ip_subnet] + '.254',
                        "IP_Subnet": i,
                        "Start_IP": i[:ip_subnet] + '.248',
                        "CustomerName": customername,
                        "regex": pattern
                    }
                ]
                ip_rows = pd.DataFrame(dataframe)
                data = pd.concat([ip_rows, data], ignore_index=True)
            if subnet_end == 30:
                pattern = '''^{}.(?:25[2-4])$'''.format(i[:ip_subnet])
                dataframe = [
                    {
                        "Department_Name": "Python",
                        "Modification_Date": tdate,
                        "End_IP": i[:ip_subnet] + '.254',
                        "IP_Subnet": i,
                        "Start_IP": i[:ip_subnet] + '.252',
                        "CustomerName": customername,
                        "regex": pattern
                    }
                ]
                ip_rows = pd.DataFrame(dataframe)
                data = pd.concat([ip_rows, data], ignore_index=True)
        else:
            duplicate_ip.append(i)
    if data.empty and len(duplicate_ip)>0:
        return ({"status": 200, "message": "data already available", "data": duplicate_ip})
        # print('++++++++++++++++++++++++++++++++++++++++++++++++',l)
    if len(duplicate_ip)<0 and not data.empty:
        data.to_sql('subnetMapping', con=mydb, if_exists='append', index=False)
        return jsonify({"status": 200, "message": "data added successfully", "data": data})
        # return data
    if len(duplicate_ip)>0 and not data.empty:
        data.to_sql('subnetMapping', con=mydb, if_exists='append', index=False)
        return ({"status": 200, "message": "data added successfully", "Data Already Available": duplicate_ip})

# %%
f=create_ip_subnet(["192.168.21.1/25","192.168.52.1/29"])

# %%
f

# %%
ip_list=["192.168.21.1/25","192.168.52.1/29"]
customername="Sattrix"
data=pd.DataFrame()
duplicate_ip=[]
db = pymysql.connect(host="localhost", user="root", password="Sattrix@123", database="NewEvol")
for i in ip_list:
    today_date = datetime.datetime.now()
    tdate = today_date.strftime("%d-%m-%Y %H:%M:%S")
    i=i.strip()
    ip_subnet = i.rfind('.')
    slash = i.rfind('/')
    subnet_end = int(i[(slash) + 1:])
    cur=db.cursor()
    query='''select CustomerName from subnetMapping where IP_Subnet='{}' '''.format(i)
    cur.execute(query)
    ip_available=cur.fetchall()
    print(ip_available)
    if not ip_available:
        if subnet_end == 24:
            pattern = '''^{}.(?:[1-9]|[1-9][0-9]|[1][0-9][0-9]|[2][0-4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
            dataframe = [
                {
                    "Department_Name": "Python",
                    "Modification_Date":tdate,
                    "End_IP": i[:ip_subnet] + '.254',
                    "IP_Subnet": i,
                    "Start_IP": i[:ip_subnet] + '.0',
                    "CustomerName":customername ,
                    "regex": pattern
                }
            ]
            ip_rows = pd.DataFrame(dataframe)
            data = pd.concat([ip_rows, data], ignore_index=True)
        if subnet_end == 25:
            pattern = '''^{}.(?:12[8-9]|1[3-9][0-9]|2[0-4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
            dataframe = [
                {
                    "Department_Name": "Python",
                    "Modification_Date": tdate,
                    "End_IP": i[:ip_subnet] + '.254',
                    "IP_Subnet": i,
                    "Start_IP": i[:ip_subnet] + '.128',
                    "CustomerName": customername,
                    "regex": pattern
                }
            ]
            ip_rows = pd.DataFrame(dataframe)
            data = pd.concat([ip_rows, data], ignore_index=True)
        if subnet_end == 26:
            pattern = '''^{}.(?:19[2-9]|2[0-4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
            dataframe = [
                {
                    "Department_Name": "Python",
                    "Modification_Date": tdate,
                    "End_IP": i[:ip_subnet] + '.254',
                    "IP_Subnet": i,
                    "Start_IP": i[:ip_subnet] + '.192',
                    "CustomerName": customername,
                    "regex": pattern
                }
            ]
            ip_rows = pd.DataFrame(dataframe)
            data = pd.concat([ip_rows, data], ignore_index=True)
        if subnet_end == 27:
            pattern = '''^{}.(?:22[4-9]|2[3-4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
            dataframe = [
                {
                    "Department_Name": "Python",
                    "Modification_Date": tdate,
                    "End_IP": i[:ip_subnet] + '.254',
                    "IP_Subnet": i,
                    "Start_IP": i[:ip_subnet] + '.224',
                    "CustomerName":customername,
                    "regex": pattern
                }
            ]
            ip_rows = pd.DataFrame(dataframe)
            data = pd.concat([ip_rows, data], ignore_index=True)
        if subnet_end == 28:
            pattern = '''^{}.(?:[2][4][0-9]|25[0-4])$'''.format(i[:ip_subnet])
            dataframe = [
                {
                    "Department_Name": "Python",
                    "Modification_Date": tdate,
                    "End_IP": i[:ip_subnet] + '.254',
                    "IP_Subnet": i,
                    "Start_IP": i[:ip_subnet] + '.240',
                    "CustomerName": customername,
                    "regex": pattern
                }
            ]
            ip_rows = pd.DataFrame(dataframe)
            data = pd.concat([ip_rows, data], ignore_index=True)
        if subnet_end == 29:
            pattern = '''^{}.(?:[2][4][8-9]|25[0-4])$'''.format(i[:ip_subnet])
            dataframe = [
                {
                    "Department_Name": "Python",
                    "Modification_Date": tdate,
                    "End_IP": i[:ip_subnet] + '.254',
                    "IP_Subnet": i,
                    "Start_IP": i[:ip_subnet] + '.248',
                    "CustomerName": customername,
                    "regex": pattern
                }
            ]
            ip_rows = pd.DataFrame(dataframe)
            data = pd.concat([ip_rows, data], ignore_index=True)
        if subnet_end == 30:
            pattern = '''^{}.(?:25[2-4])$'''.format(i[:ip_subnet])
            dataframe = [
                {
                    "Department_Name": "Python",
                    "Modification_Date": tdate,
                    "End_IP": i[:ip_subnet] + '.254',
                    "IP_Subnet": i,
                    "Start_IP": i[:ip_subnet] + '.252',
                    "CustomerName": customername,
                    "regex": pattern
                }
            ]
            ip_rows = pd.DataFrame(dataframe)
            data = pd.concat([ip_rows, data], ignore_index=True)
    else:
        duplicate_ip.append(i)
print(data)
if data.empty and len(duplicate_ip)>0:
#     return ({"status": 200, "message": "data already available", "data": duplicate_ip})
    print('1')
if len(duplicate_ip)<0 and not data.empty:
#     data.to_sql('subnetMapping', con=mydb, if_exists='append', index=False)
#     return jsonify({"status": 200, "message": "data added successfully", "data": data})
#     return data
    print("2")
if len(duplicate_ip)>0 and data.empty:
#     data.to_sql('subnetMapping', con=mydb, if_exists='append', index=False)
#     return ({"status": 200, "message": "data added successfully", "Data Already Available": duplicate_ip})
    print("3")
else:
    print("4")
# Out:
# ()
# ()
#   Department_Name    Modification_Date          End_IP        IP_Subnet  \
# 0          Python  08-09-2023 12:53:13  192.168.52.254  192.168.52.1/29
# 1          Python  08-09-2023 12:53:13  192.168.21.254  192.168.21.1/25
#
#          Start_IP CustomerName  \
# 0  192.168.52.248      Sattrix
# 1  192.168.21.128      Sattrix
#
#                                                regex
# 0               ^192.168.52.(?:[2][4][8-9]|25[0-4])$
# 1  ^192.168.21.(?:12[8-9]|1[3-9][0-9]|2[0-4][0-9]...
# 4

# %%
not len(duplicate_ip)>0
# Out:
# True

# %%
# duplicate_ip=[1,]

# %%
not len(duplicate_ip)<0

# %%
not data.empty

# %%
not len(duplicate_ip)>0

# %%
not data.empty

# %%
duplicate_ip=[2,5]

# %%
len(duplicate_ip) <=0 and not data.empty

# %%
len(duplicate_ip) > 0 and not data.empty

# %%
data.empty and len(duplicate_ip) >=0

# %%
db = pymysql.connect(host="localhost", user="root", password="Sattrix@123", database="NewEvol")

# %%
data=pd.read_sql('''select Modification_Date,IP_Subnet ,Start_IP, End_IP, CustomerName from subnetMapping ''',con=db)

# %%
data=pd.read_sql('''select Modification_Date,IP_Subnet ,Start_IP, End_IP, CustomerName from subnetMapping order by Modification_Date DESC ''',con=db)

# %%
data

# %%
from pandasql import sqldf
n=sqldf('''select * from data group by CustomerName''')

# %%
n

# %%
len(duplicate_ip)>0

# %%
len(duplicate_ip)

# %%
len(duplicate_ip)<0

# %%
5>0

# %%
list_ip=[["125.165.721.130","125.165.721.225"],["192.168.25.11","192.168.25.124"]]

# %%
for i in list_ip:
    if '125' in i:
        print('hello')

# %%
i[0]

# %%
int(ipendvalue)-int(ipstartvalue)<10

# %%
ipendvalue=124
ipstartvalue=11

# %%
("Initial Access", "Execution", "Persistence", "Privilege Escalation", "Defense Evasion",
                   "Credential Access", "Discovery", "Lateral Movement", "Collection", "Command and Control",
                   "Exfiltration", "Impact","Resource Development","Reconnaissance")== ("Initial Access", "Execution", "Persistence", "Privilege Escalation", "Defense Evasion",
                   "Credential Access", "Discovery", "Lateral Movement", "Collection", "Command and Control",
                   "Exfiltration", "Impact","Resource Development","Reconnaissance")

# %%
d=pd.read_csv('demo_inci.csv')

# %%
d

# %%
d.reset_index(drop=True)

# %%
d[d.src.str.match('^45.112.178.18$')]

# %%
 db = pymysql.connect(host="localhost", user="root", password="Sattrix@123", database="NewEvol")

# %%
cur=db.cursor()
cur.execute('''delete from subnetMapping where Modification_Date like "%29-08-2023%" ''')
db.commit()

# %% [raw]
# cur.fetchall()

# %%
cur.fetchall()

# %%
field="192.168"
limit_value=10
query = "select Modification_Date,Department_Name,End_IP,IP_Subnet,Start_IP,CustomerName from subnetMapping where (Modification_Date like '%{}%' OR Department_Name like '%{}%' OR End_IP like '%{}%' OR IP_Subnet like '%{}%' OR Start_IP like '%{}%' OR CustomerName like '%{}%' ) Order by Modification_Date desc limit {}, 10".format(
                field,field,field,field,field,field,limit_value)
cur.execute(query)
cur.fetchall()

# %%
 MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Initial Access" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub1),0) ) END) AS Initial_Access,
            MAX(CASE WHEN Technique_Name = 'Execution' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Execution" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub2),0) ) END) AS Execution,
            MAX(CASE WHEN Technique_Name = 'Persistence' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Persistence" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub3),0) ) END) AS Persistence,
            MAX(CASE WHEN Technique_Name = 'Privilege Escalation' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Privilege Escalation" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub4),0) ) END)  AS Privilege_Escalation,
            MAX(CASE WHEN Technique_Name = 'Defense Evasion' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Defense Evasion" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub5),0) ) END)  AS Defense_Evasion,
            MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub6),0) ) END)  AS Credential_Access,
            MAX(CASE WHEN Technique_Name = 'Discovery' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Discovery" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub7),0) ) END)  AS Discovery,
            MAX(CASE WHEN Technique_Name = 'Lateral Movement' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Lateral Movement" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub8),0) ) END)  AS Lateral_Movement,
            MAX(CASE WHEN Technique_Name = 'Collection' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Collection" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub9),0) ) END)  AS Collection,
            MAX(CASE WHEN Technique_Name = 'Command and Control' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Command and Control" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub10),0) ) END)  AS Command_and_Control,
            MAX(CASE WHEN Technique_Name = 'Exfiltration' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Exfiltration" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub11),0) ) END)  AS Exfiltration,
            MAX(CASE WHEN Technique_Name = 'Impact' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Impact" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub12),0) ) END)  AS Impact,
            MAX(CASE WHEN Technique_Name = 'Resource Development' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Resource Development" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub13),0) ) END)  AS Resource_Development,
            MAX(CASE WHEN Technique_Name = 'Reconnaissance' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Reconnaissance" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub14),0) ) END)  AS Reconnaissance

                 FROM Rule_MitreTechnique where (UserId={} OR RuleGroup IN ({}))
                 GROUP BY Technique_Name,Sub_Technique
                 ORDER BY {} ,{}""".

# %%
d='''MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub6),0) ) END)  AS Credential_Access,'''

# %%
R='''MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub6),0) ) END)  AS Credential_Access,'''

# %%
r=R.split(' ')

# %%
d

# %%
for i in d:
    if i not in r:
        print(i)
    else:
        continue

# %%
i==d

# %%
print(r)

# %%
print(d)

# %%
MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Initial Access" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub1),0) ) END) AS Initial_Access,
                                        MAX(CASE WHEN Technique_Name = 'Execution' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Execution" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub2),0) ) END) AS Execution,
                                        MAX(CASE WHEN Technique_Name = 'Persistence' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Persistence" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub3),0) ) END) AS Persistence,
                                        MAX(CASE WHEN Technique_Name = 'Privilege Escalation' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Privilege Escalation" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub4),0) ) END)  AS Privilege_Escalation,
                                        MAX(CASE WHEN Technique_Name = 'Defense Evasion' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Defense Evasion" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub5),0) ) END)  AS Defense_Evasion,
                                        MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub6),0) ) END)  AS Credential_Access,
                                        MAX(CASE WHEN Technique_Name = 'Discovery' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Discovery" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub7),0) ) END)  AS Discovery,
                                        MAX(CASE WHEN Technique_Name = 'Lateral Movement' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Lateral Movement" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub8),0) ) END)  AS Lateral_Movement,
                                        MAX(CASE WHEN Technique_Name = 'Collection' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Collection" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub9),0) ) END)  AS Collection,
                                        MAX(CASE WHEN Technique_Name = 'Command and Control' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Command and Control" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub10),0) ) END)  AS Command_and_Control,
                                        MAX(CASE WHEN Technique_Name = 'Exfiltration' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Exfiltration" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub11),0) ) END)  AS Exfiltration,
                                        MAX(CASE WHEN Technique_Name = 'Impact' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Impact" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub12),0) ) END)  AS Impact,
                                        MAX(CASE WHEN Technique_Name = 'Resource Development' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Resource Development" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub13),0) ) END)  AS Resource_Development,
                                        MAX(CASE WHEN Technique_Name = 'Reconnaissance' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Reconnaissance" CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub14),0) ) END)  AS Reconnaissance

# %%
d=["Modification_Date like '%%' AND Department_Name like '%%' AND End_IP like '%%' AND  IP_Subnet like '%%' AND Start_IP like '%%' AND CustomerName like '%hsc%'"]

# %%
''.join(d)

# %%
db = pymysql.connect(host="10.172.194.43", user="root", password="Sattrix@123", database="NewEvol")

# %%
custname="SATTRIX"

# %%
result = pd.read_sql(""" SELECT
                MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Initial Access" AND CustomerName='{}' ORDER BY StartTime DESC) as sub1),0) ) END) AS Initial_Access,
                MAX(CASE WHEN Technique_Name = 'Execution' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Execution" AND CustomerName='{}' ORDER BY StartTime DESC ) as sub2),0) ) END) AS Execution,
                MAX(CASE WHEN Technique_Name = 'Persistence' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Persistence" AND CustomerName='{}' ORDER BY StartTime DESC) as sub3),0) ) END) AS Persistence,
                MAX(CASE WHEN Technique_Name = 'Privilege Escalation' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Privilege Escalation" AND CustomerName='{}' ORDER BY StartTime DESC) as sub4),0) ) END)  AS Privilege_Escalation,
                MAX(CASE WHEN Technique_Name = 'Defense Evasion' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Defense Evasion" AND CustomerName='{}' ORDER BY StartTime DESC) as sub5),0) ) END)  AS Defense_Evasion,
                MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT *  FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" AND CustomerName='{}' ORDER BY StartTime DESC) as sub6),0) ) END)  AS Credential_Access,
                MAX(CASE WHEN Technique_Name = 'Discovery' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Discovery" AND CustomerName='{}' ORDER BY StartTime DESC) as sub7),0) ) END)  AS Discovery,
                MAX(CASE WHEN Technique_Name = 'Lateral Movement' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Lateral Movement" AND CustomerName='{}' ORDER BY StartTime DESC) as sub8),0) ) END)  AS Lateral_Movement,
                MAX(CASE WHEN Technique_Name = 'Collection' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Collection" AND CustomerName='{}' ORDER BY StartTime DESC) as sub9),0) ) END)  AS Collection,
                MAX(CASE WHEN Technique_Name = 'Command and Control' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Command and Control" AND CustomerName='{}' ORDER BY StartTime DESC) as sub10),0) ) END)  AS Command_and_Control,
                MAX(CASE WHEN Technique_Name = 'Exfiltration' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Exfiltration" AND CustomerName='{}' ORDER BY StartTime DESC) as sub11),0) ) END)  AS Exfiltration,
                MAX(CASE WHEN Technique_Name = 'Impact' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Impact" AND CustomerName='{}' ORDER BY StartTime DESC) as sub12),0) ) END)  AS Impact,
                MAX(CASE WHEN Technique_Name = 'Resource Development' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Resource Development" AND CustomerName='{}' ORDER BY StartTime DESC) as sub13),0) ) END)  AS Resource_Development,
                MAX(CASE WHEN Technique_Name = 'Reconnaissance' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Reconnaissance" AND CustomerName='{}' ORDER BY StartTime DESC) as sub14),0) ) END)  AS Reconnaissance
    
    
                     FROM Rule_MitreTechnique
                     GROUP BY Technique_Name,Sub_Technique""".format(custname, custname, custname, custname, custname,
                                                                     custname, custname, custname, custname, custname,
                                                                     custname, custname, custname, custname), con=db)

# %%
result

# %%
Defense_Evasion = result["Defense_Evasion"].dropna()
Initial_Access = result["Initial_Access"].dropna()
Execution = result["Execution"].dropna()
Persistence = result["Persistence"].dropna()
Privilege_Escalation = result["Privilege_Escalation"].dropna()
Credential_Access = result["Credential_Access"].dropna()
Discovery = result["Discovery"].dropna()
Lateral_Movement = result["Lateral_Movement"].dropna()
Collection = result["Collection"].dropna()
Command_and_Control = result["Command_and_Control"].dropna()
Exfiltration = result["Exfiltration"].dropna()
Impact = result["Impact"].dropna()
Resource_Development = result["Resource_Development"].dropna()
Reconnaissance = result["Reconnaissance"].dropna()

# %%
Credential_Access

# %%
df1 = pd.DataFrame(Defense_Evasion).reset_index(drop=True)
df2 = pd.DataFrame(Initial_Access).reset_index(drop=True)
df3 = pd.DataFrame(Execution).reset_index(drop=True)
df4 = pd.DataFrame(Persistence).reset_index(drop=True)
df5 = pd.DataFrame(Privilege_Escalation).reset_index(drop=True)
df6 = pd.DataFrame(Credential_Access).reset_index(drop=True)
df7 = pd.DataFrame(Discovery).reset_index(drop=True)
df8 = pd.DataFrame(Lateral_Movement).reset_index(drop=True)
df9 = pd.DataFrame(Collection).reset_index(drop=True)
df10 = pd.DataFrame(Command_and_Control).reset_index(drop=True)
df11 = pd.DataFrame(Exfiltration).reset_index(drop=True)
df12 = pd.DataFrame(Impact).reset_index(drop=True)
df13 = pd.DataFrame(Resource_Development).reset_index(drop=True)
df14 = pd.DataFrame(Reconnaissance).reset_index(drop=True)

dd1 = df1.join(df2)
dd2 = dd1.join(df3)
dd3 = dd2.join(df4)
dd4 = dd3.join(df5)
dd5 = dd4.join(df6)
dd6 = dd5.join(df7)
dd7 = dd6.join(df8)
dd8 = dd7.join(df9)
dd9 = dd8.join(df10)
dd10 = dd9.join(df11)
dd11 = dd10.join(df12)
dd12 = dd11.join(df13)
dd13 = dd12.join(df14)

# %%
dd13

# %%
df1

# %%
pd.read_sql(""" SELECT MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Initial Access" AND CustomerName='{}' ORDER BY StartTime DESC) as sub1),0) ) END) AS Initial_Access,
                FROM Rule_MitreTechnique
                     GROUP BY Technique_Name,Sub_Technique""".format(custname), con=db)

# %%
pd.read_sql(""" SELECT
                MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Initial Access" AND CustomerName='{}' ORDER BY StartTime DESC) as sub1),0) ) END) AS Initial_Access,
                MAX(CASE WHEN Technique_Name = 'Execution' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Execution" AND CustomerName='{}' ORDER BY StartTime DESC ) as sub2),0) ) END) AS Execution,
                MAX(CASE WHEN Technique_Name = 'Persistence' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Persistence" AND CustomerName='{}' ORDER BY StartTime DESC) as sub3),0) ) END) AS Persistence,
                MAX(CASE WHEN Technique_Name = 'Privilege Escalation' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Privilege Escalation" AND CustomerName='{}' ORDER BY StartTime DESC) as sub4),0) ) END)  AS Privilege_Escalation,
                MAX(CASE WHEN Technique_Name = 'Defense Evasion' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Defense Evasion" AND CustomerName='{}' ORDER BY StartTime DESC) as sub5),0) ) END)  AS Defense_Evasion,
                MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT *  FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" AND CustomerName='{}' ORDER BY StartTime DESC) as sub6),0) ) END)  AS Credential_Access,
                MAX(CASE WHEN Technique_Name = 'Discovery' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Discovery" AND CustomerName='{}' ORDER BY StartTime DESC) as sub7),0) ) END)  AS Discovery,
                MAX(CASE WHEN Technique_Name = 'Lateral Movement' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Lateral Movement" AND CustomerName='{}' ORDER BY StartTime DESC) as sub8),0) ) END)  AS Lateral_Movement,
                MAX(CASE WHEN Technique_Name = 'Collection' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Collection" AND CustomerName='{}' ORDER BY StartTime DESC) as sub9),0) ) END)  AS Collection,
                MAX(CASE WHEN Technique_Name = 'Command and Control' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Command and Control" AND CustomerName='{}' ORDER BY StartTime DESC) as sub10),0) ) END)  AS Command_and_Control,
                MAX(CASE WHEN Technique_Name = 'Exfiltration' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Exfiltration" AND CustomerName='{}' ORDER BY StartTime DESC) as sub11),0) ) END)  AS Exfiltration,
                MAX(CASE WHEN Technique_Name = 'Impact' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Impact" AND CustomerName='{}' ORDER BY StartTime DESC) as sub12),0) ) END)  AS Impact,
                MAX(CASE WHEN Technique_Name = 'Resource Development' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Resource Development" AND CustomerName='{}' ORDER BY StartTime DESC) as sub13),0) ) END)  AS Resource_Development,
                MAX(CASE WHEN Technique_Name = 'Reconnaissance' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Reconnaissance" AND CustomerName='{}' ORDER BY StartTime DESC) as sub14),0) ) END)  AS Reconnaissance
    
    
                     FROM Rule_MitreTechnique
                     GROUP BY Technique_Name,Sub_Technique""".format(custname, custname, custname, custname, custname,
                                                                     custname, custname, custname, custname, custname,
                                                                     custname, custname, custname, custname), con=db)

# %%
d=pd.read_sql('''select * from vw_GetAlertIdByMitre order by StartTime DESC''',con=db)

# %%
r

# %%
r=pd.read_sql('''select * from Rule_MitreTechnique''',con=db)

# %%
d

# %%
result = sqldf(""" SELECT
                MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Initial Access" AND CustomerName='{}' group by RuleId),0) ) END) AS Initial_Access,
                MAX(CASE WHEN Technique_Name = 'Execution' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Execution" AND CustomerName='{}' group by RuleId ) as sub2),0) ) END) AS Execution,
                MAX(CASE WHEN Technique_Name = 'Persistence' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Persistence" AND CustomerName='{}' group by RuleId) as sub3),0) ) END) AS Persistence,
                MAX(CASE WHEN Technique_Name = 'Privilege Escalation' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM (SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Privilege Escalation" AND CustomerName='{}' group by RuleId) as sub4),0) ) END)  AS Privilege_Escalation,
                MAX(CASE WHEN Technique_Name = 'Defense Evasion' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Defense Evasion" AND CustomerName='{}' group by RuleId) as sub5),0) ) END)  AS Defense_Evasion,
                MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT *  FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" AND CustomerName='{}' group by RuleId) as sub6),0) ) END)  AS Credential_Access,
                MAX(CASE WHEN Technique_Name = 'Discovery' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Discovery" AND CustomerName='{}' group by RuleId) as sub7),0) ) END)  AS Discovery,
                MAX(CASE WHEN Technique_Name = 'Lateral Movement' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Lateral Movement" AND CustomerName='{}' group by RuleId) as sub8),0) ) END)  AS Lateral_Movement,
                MAX(CASE WHEN Technique_Name = 'Collection' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Collection" AND CustomerName='{}' group by RuleId) as sub9),0) ) END)  AS Collection,
                MAX(CASE WHEN Technique_Name = 'Command and Control' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Command and Control" AND CustomerName='{}' group by RuleId) as sub10),0) ) END)  AS Command_and_Control,
                MAX(CASE WHEN Technique_Name = 'Exfiltration' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Exfiltration" AND CustomerName='{}' group by RuleId) as sub11),0) ) END)  AS Exfiltration,
                MAX(CASE WHEN Technique_Name = 'Impact' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Impact" AND CustomerName='{}' group by RuleId) as sub12),0) ) END)  AS Impact,
                MAX(CASE WHEN Technique_Name = 'Resource Development' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Resource Development" AND CustomerName='{}' group by RuleId) as sub13),0) ) END)  AS Resource_Development,
                MAX(CASE WHEN Technique_Name = 'Reconnaissance' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT * FROM d WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Reconnaissance" AND CustomerName='{}' group by RuleId) as sub14),0) ) END)  AS Reconnaissance
    
    
                     FROM r
                     GROUP BY Technique_Name,Sub_Technique""".format(custname, custname, custname, custname, custname,
                                                                     custname, custname, custname, custname, custname,
                                                                     custname, custname, custname, custname))

# %%
pd.read_sql('''(SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM (select * from vw_GetAlertIdByMitre order by StartTime DESC) as sub1''',con=db)

# %%
 result = pd.read_sql(""" SELECT
                MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Initial Access" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub1),0) ) END) AS Initial_Access,
                MAX(CASE WHEN Technique_Name = 'Execution' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Execution" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC ) as sub2),0) ) END) AS Execution,
                MAX(CASE WHEN Technique_Name = 'Persistence' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Persistence" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub3),0) ) END) AS Persistence,
                MAX(CASE WHEN Technique_Name = 'Privilege Escalation' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Privilege Escalation" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub4),0) ) END)  AS Privilege_Escalation,
                MAX(CASE WHEN Technique_Name = 'Defense Evasion' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Defense Evasion" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub5),0) ) END)  AS Defense_Evasion,
                MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id , RuleId FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub6),0) ) END)  AS Credential_Access,
                MAX(CASE WHEN Technique_Name = 'Discovery' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Discovery" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub7),0) ) END)  AS Discovery,
                MAX(CASE WHEN Technique_Name = 'Lateral Movement' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Lateral Movement" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub8),0) ) END)  AS Lateral_Movement,
                MAX(CASE WHEN Technique_Name = 'Collection' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Collection" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub9),0) ) END)  AS Collection,
                MAX(CASE WHEN Technique_Name = 'Command and Control' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Command and Control" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub10),0) ) END)  AS Command_and_Control,
                MAX(CASE WHEN Technique_Name = 'Exfiltration' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Exfiltration" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub11),0) ) END)  AS Exfiltration,
                MAX(CASE WHEN Technique_Name = 'Impact' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Impact" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub12),0) ) END)  AS Impact,
                MAX(CASE WHEN Technique_Name = 'Resource Development' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Resource Development" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub13),0) ) END)  AS Resource_Development,
                MAX(CASE WHEN Technique_Name = 'Reconnaissance' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Reconnaissance" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub14),0) ) END)  AS Reconnaissance
    
    
                     FROM Rule_MitreTechnique
                     GROUP BY Technique_Name,Sub_Technique""".format(custname, custname, custname, custname, custname,
                                                                     custname, custname, custname, custname, custname,
                                                                     custname, custname, custname, custname), con=db)

# %%
result

# %%
result.to_string()

# %%
d=pd.read_sql('''select * from vw_GetAlertIdByMitre order by StartTime DESC''',con=db)
sqldf("select * from d group by RuleId")

# %%
d

# %%
db = pymysql.connect(host="10.172.194.43", user="root", password="Sattrix@123", database="NewEvol")
d=pd.read_sql('''select * from vw_GetAlertIdByMitre group by RuleId order by StartTime DESC''',con=db)
d

# %%
d=pd.read_sql('''select * from vw_GetAlertIdByMitre order by StartTime DESC''',con=db)
sqldf("select * from d group by RuleId")

# %%
select l.* from table l inner join (select m_id, max(timestamp) as latest from table group by m_id)
r
  on l.timestamp = r.latest and l.m_id = r.m_id
order by timestamp desc

# %%
d=pd.read_sql('''select * from table vw_GetAlertIdByMitre inner join (select RuleId, max(StartTime) as
                latest from table group by RuleId)r on StartTime =r.latest and RuleId=r.RuleId
                order by StartTime DESC''',con=db)

# %%
pd.read_sql('''select Alert_Id,StartTime from(SELECT RuleId, Alert_Id,StartTime FROM 
                (SELECT * FROM vw_GetAlertIdByMitre ORDER BY StartTime DESC) 
                as d order BY d.StartTime DESC) as r group by RuleId''',con=db)

# %%
SELECT RuleId, Alert_Id FROM (SELECT * FROM vw_GetAlertIdByMitre ORDER BY StartTime DESC) as new GROUP BY RuleId ;

# %%
'''SELECT
                MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Initial Access" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub1),0) ) END) AS Initial_Access,
                MAX(CASE WHEN Technique_Name = 'Execution' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Execution" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC ) as sub2),0) ) END) AS Execution,
                MAX(CASE WHEN Technique_Name = 'Persistence' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Persistence" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub3),0) ) END) AS Persistence,
                MAX(CASE WHEN Technique_Name = 'Privilege Escalation' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Privilege Escalation" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub4),0) ) END)  AS Privilege_Escalation,
                MAX(CASE WHEN Technique_Name = 'Defense Evasion' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Defense Evasion" AND CustomerName='{}'  GROUP BY RuleId ORDER BY StartTime DESC) as sub5),0) ) END)  AS Defense_Evasion,
                MAX(CASE WHEN Technique_Name = 'Credential Access' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id , RuleId FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Credential Access" AND CustomerName='{}'   GROUP BY RuleId ORDER BY StartTime DESC) as sub6),0) ) END)  AS Credential_Access,
                MAX(CASE WHEN Technique_Name = 'Discovery' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Discovery" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub7),0) ) END)  AS Discovery,
                MAX(CASE WHEN Technique_Name = 'Lateral Movement' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Lateral Movement" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub8),0) ) END)  AS Lateral_Movement,
                MAX(CASE WHEN Technique_Name = 'Collection' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Collection" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub9),0) ) END)  AS Collection,
                MAX(CASE WHEN Technique_Name = 'Command and Control' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Command and Control" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub10),0) ) END)  AS Command_and_Control,
                MAX(CASE WHEN Technique_Name = 'Exfiltration' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Exfiltration" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub11),0) ) END)  AS Exfiltration,
                MAX(CASE WHEN Technique_Name = 'Impact' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Impact" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub12),0) ) END)  AS Impact,
                MAX(CASE WHEN Technique_Name = 'Resource Development' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Resource Development" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub13),0) ) END)  AS Resource_Development,
                MAX(CASE WHEN Technique_Name = 'Reconnaissance' THEN CONCAT(Sub_Technique,'#',IFNULL((SELECT GROUP_CONCAT(Alert_Id ORDER BY Alert_Id) AS Alert_Id FROM(SELECT Alert_Id FROM vw_GetAlertIdByMitre WHERE MitreSubName = Sub_Technique AND Rule_MITREName = "Reconnaissance" AND CustomerName='{}' GROUP BY RuleId ORDER BY StartTime DESC) as sub14),0) ) END)  AS Reconnaissance
    
    
                     FROM Rule_MitreTechnique
                     GROUP BY Technique_Name,Sub_Technique'''

# %%
'''SELECT MAX(CASE WHEN Technique_Name = 'Initial Access' THEN CONCAT(Sub_Technique,'#',IFNULL(SELECT MAX(Alert_Id)
,RuleId,StartTime  FROM (select * from NewEvol.vw_GetAlertIdByMitre WHERE  Rule_MITREName = "Credential Access"
AND CustomerName='SATTRIX' order by StartTime DESC) as d  group BY d.RuleId),0) ) END) AS Initial_Access'''

# %%
db = pymysql.connect(host="10.172.194.43", user="root", password="Sattrix@123", database="NewEvol")

# %%
result = pd.read_sql(""" SELECT ROW_NUMBER() Over (Order by LogsCreateDate  DESC) As SR, logs_adminmodule.UserId, User.UserName, logs_adminmodule.LogsCreateDate,logs_adminmodule.LogsDetails,logs_adminmodule.TableAffected FROM logs_adminmodule
                                       INNER JOIN `User` ON logs_adminmodule.UserId = User.UserId
                                       order by UserId DESC limit 0,10""", con=db)
result
# Out:
# /tmp/ipykernel_35252/3707728540.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result = pd.read_sql(""" SELECT ROW_NUMBER(start=0) Over (Order by LogsCreateDate  DESC) As SR, logs_adminmodule.UserId, User.UserName, logs_adminmodule.LogsCreateDate,logs_adminmodule.LogsDetails,logs_adminmodule.TableAffected FROM logs_adminmodule
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:2202, in SQLiteDatabase.execute(self, sql, params)
#    2201 try:
# -> 2202     cur.execute(sql, *args)
#    2203     return cur
#
# File ~/.local/lib/python3.10/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# ...

# %%
result
# Out:
#    UserId      UserName      LogsCreateDate   LogsDetails TableAffected
# 0     405  naresh kumar 2023-09-07 14:31:09  User Updated          User
# 1     405  naresh kumar 2023-09-05 14:20:04  User Updated          User
# 2     405  naresh kumar 2023-09-05 16:24:49  User Updated          User
# 3     405  naresh kumar 2023-09-05 16:29:00  User Updated          User
# 4     405  naresh kumar 2023-09-06 14:16:46  User Updated          User
# 5     405  naresh kumar 2023-09-06 14:52:07  User Updated          User
# 6     405  naresh kumar 2023-09-07 11:55:49  User Updated          User
# 7     405  naresh kumar 2023-09-07 11:56:38  User Updated          User
# 8     405  naresh kumar 2023-09-07 11:57:09  User Updated          User
# 9     405  naresh kumar 2023-09-07 11:58:15  User Updated          User

# %%
from pandasql import sqldf
sqldf('''select * from result''')
# Out:
#    UserId      UserName              LogsCreateDate   LogsDetails  \
# 0     405  naresh kumar  2023-09-07 14:31:09.000000  User Updated
# 1     405  naresh kumar  2023-09-05 14:20:04.000000  User Updated
# 2     405  naresh kumar  2023-09-05 16:24:49.000000  User Updated
# 3     405  naresh kumar  2023-09-05 16:29:00.000000  User Updated
# 4     405  naresh kumar  2023-09-06 14:16:46.000000  User Updated
# 5     405  naresh kumar  2023-09-06 14:52:07.000000  User Updated
# 6     405  naresh kumar  2023-09-07 11:55:49.000000  User Updated
# 7     405  naresh kumar  2023-09-07 11:56:38.000000  User Updated
# 8     405  naresh kumar  2023-09-07 11:57:09.000000  User Updated
# 9     405  naresh kumar  2023-09-07 11:58:15.000000  User Updated
#
#   TableAffected
# 0          User
# 1          User
# 2          User
# 3          User
# 4          User
# 5          User
# 6          User
# 7          User
# 8          User
# 9          User

# %%
def report_notification_alert(report_id, report_name, report_notification,customerName,save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'gmail'
            EmailConfigPort = 587
            EmailFromId = 'nareshsisodiya1996@gmail.com'
            EmailPassword = 'yszbenixyrdrioei'
#             emailto = ['sanchit.shewade@sattrixsoftware.com', 'shriram.toradmal@sattrixsoftware.com']
            emailto=['naresh_kumar@sattrixsoftware.com','jyoti_pradhan@sattrixsoftware.com']
            EmailSubject = 'Report_Alert'
            EmailTypeDescr = "Report Generated Successfully For Report Name {}  \nThank's & Regards, \n {}".format(report_name,{EmailFromId})
            msg = MIMEMultipart()
            msg['From'] = EmailFromId
            msg['To'] = ", ".join(emailto)
            msg['Subject'] = EmailSubject
            msg.attach(MIMEText(EmailTypeDescr))
            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            print("Hello")
            mailserver.login(EmailFromId, EmailPassword)
            print("Login to Email")
            mailserver.sendmail(EmailFromId, emailto, msg.as_string())
            #print("Email has been sent.")
            # Should be mailServer.quit(), but that crashes...
            mailserver.close()
        except smtplib.SMTPDataError as e:
            print("error while sending email: {}".format(e))

    if report_notification == 2:
        dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name,"customerName":customerName[1:-1]}
        #print(dict3)
        # dict3=json.dumps(dict3)
        url = 'https://192.168.21.198:8082/api/rulereport'
        response = requests.post(url, json=dict3,verify=False)

# %%
report_id=123
report_name="chart and table"
report_notification=1
customerName="SATTRIX"
save_location="/opt/NewEvol/Current/NewEvol_Solr/Flask_App/report_pdf/Snehal_report1_1688965612487.pdf"
report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# Cell In[38], line 6
#       4 customerName="SATTRIX"
#       5 save_location="/opt/NewEvol/Current/NewEvol_Solr/Flask_App/report_pdf/Snehal_report1_1688965612487.pdf"
# ----> 6 report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
#
# Cell In[37], line 17, in report_notification_alert(report_id, report_name, report_notification, customerName, save_location)
#      15 msg['Subject'] = EmailSubject
#      16 msg.attach(MIMEText(EmailTypeDescr))
# ---> 17 mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
#      18 mailserver.ehlo()
#      19 mailserver.starttls()
#
# File /usr/lib/python3.10/smtplib.py:255, in SMTP.__init__(self, host, port, local_hostname, timeout, source_address)
#     252 self._auth_challenge_count = 0
#     254 if host:
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import mimetypes
from email.mime.base import MIMEBase
from email import encoders
from datetime import datetime
report_id=123
report_name="chart and table"
report_notification=1
customerName="SATTRIX"
save_location="/opt/NewEvol/Current/NewEvol_Solr/Flask_App/report_pdf/Snehal_report1_1688965612487.pdf"
def report_notification_alert(report_id, report_name, report_notification,customerName,save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'smtp.office365.com'
            EmailConfigPort = 587
            EmailFromId = 'nareshsisodiya1996@gmail.com'
            EmailPassword = 'yszbenixyrdrioei'
            pdf_file_path=save_location
#             mysql=pymysql.connect()
#             cur = mysql.connection.cursor()
#             cur.execute("SELECT Report_EmailTo FROM Report_ListInfo WHERE Report_Id={}".format(report_id))
            emailto=['naresh_kumar@sattrixsoftware.com','jyoti_pradhan@sattrixsoftware.com']
#             emailto=emailto["Report_EmailTo"].split(",") #['sanchit.shewade@sattrixsoftware.com', 'shriram.toradmal@sattrixsoftware.com']
            EmailSubject = 'Report_Alert'
            EmailTypeDescr = "Report Generated Successfully For Report Name {}  \nThank You".format(report_name)
            with open(pdf_file_path, 'rb') as f:
                pdf_content = f.read()

 

            mime_type, encoding = mimetypes.guess_type(pdf_file_path)

 

            if mime_type is None:
                mime_type = 'application/octet-stream'

 

            if pdf_file_path.endswith(".pdf"):
                attachment = MIMEBase(mime_type, 'pdf', filename=os.path.basename(pdf_file_path))
            elif pdf_file_path.endswith(".xlsx") or pdf_file_path.endswith('xls'):
                attachment = MIMEBase(mime_type, 'xlsx', filename=os.path.basename(pdf_file_path))
            else:
                attachment = MIMEBase(mime_type, 'csv', filename=os.path.basename(pdf_file_path))

 

            attachment.set_payload(pdf_content)

 

            encoders.encode_base64(attachment)

 

            email = MIMEMultipart()

 

            email['From'] = EmailFromId
            email['To'] =','.join(emailto)
            email['Subject'] = EmailSubject
            email.attach(MIMEText(EmailTypeDescr))
            email.attach(attachment)

 

            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            mailserver.login(EmailFromId, EmailPassword)
            mailserver.sendmail(EmailFromId, emailto, email.as_string())
            mailserver.close()
            print("success")
            return jsonify({"msg":"email send successfully"})
        except smtplib.SMTPDataError as e:
            return jsonify({"msg":str(e)})

 

    if report_notification == 2:
        try:
            dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name,"customerName":customerName[1:-1]}
            url = 'https://192.168.21.198:8082/api/rulereport'
            response = requests.post(url, json=dict3,verify=False)
            print(dict3)
        except Exception as e:
             return jsonify({"msg":str(e)})
report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 95
#      93         except Exception as e:
#      94              return jsonify({"msg":str(e)})
# ---> 95 report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
#
# Cell In[42], line 45, in report_notification_alert(report_id, report_name, report_notification, customerName, save_location)
#      40     mime_type = 'application/octet-stream'
#      44 if pdf_file_path.endswith(".pdf"):
# ---> 45     attachment = MIMEBase(mime_type, 'pdf', filename=os.path.basename(pdf_file_path))
#      46 elif pdf_file_path.endswith(".xlsx") or pdf_file_path.endswith('xls'):
#      47     attachment = MIMEBase(mime_type, 'xlsx', filename=os.path.basename(pdf_file_path))
#
# NameError: name 'os' is not defined

# %%
# EmailConfigHost = 'smtp.office365.com'
EmailConfigPort = 587
EmailFromId = 'nareshsisodiya1996@gmail.com'
EmailPassword = 'yszbenixyrdrioei'
emailto=['naresh_kumar@sattrixsoftware.com','jyoti_pradhan@sattrixsoftware.com']
EmailSubject = 'Report_Alert'
EmailTypeDescr = "Report Generated Successfully For Report Name {} \nThank You".format(report_name)
msg = MIMEMultipart()
msg['From'] = EmailFromId
msg['To'] = emailto
msg['Subject'] = EmailSubject
msg.attach(MIMEText(EmailTypeDescr))
mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
mailserver.ehlo()
mailserver.starttls()
mailserver.ehlo()
mailserver.login(EmailFromId, EmailPassword)

mailserver.sendmail(EmailFromId, emailto, msg.as_string())

# Should be mailServer.quit(), but that crashes...
mailserver.close()
logger.debug("Email sent !!")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[43], line 17
#      15 mailserver.starttls()
#      16 mailserver.ehlo()
# ---> 17 mailserver.login(EmailFromId, EmailPassword)
#      19 mailserver.sendmail(EmailFromId, emailto, msg.as_string())
#      21 # Should be mailServer.quit(), but that crashes...
#
# File /usr/lib/python3.10/smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File /usr/lib/python3.10/smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
# ...

# %%
from pretty_html_table import build_table
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 from pretty_html_table import build_table
#
# ModuleNotFoundError: No module named 'pretty_html_table'

# %%
import re
from smtplib import *
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from pretty_html_table import build_table
from email.message import EmailMessage


sender="nareshsisodiya1996@gmail.com"
rec="naresh_kumar@sattrixsoftware.com"
password='yszbenixyrdrioei'

conn=pymysql.connect(host="192.168.21.95", user="test", password="Sattrix@123", database="Trainings")
d=pd.read_sql("select * from SMPT",conn)
d=pd.DataFrame(d)
d=build_table(d,"blue_light")

msg=EmailMessage()
# msg['subject']='Sattrix Software'
# msg['body']="Hello Welcome To Sattrix"
subject='Sattrix Software'
body="Hello Welcome To Sattrix"

message=f"subject:{subject} \n\n {body} \n\n{d}"
# d=msg.set_content(d,subtype='html')


server=SMTP("smtp.gmail.com",587)
server.starttls()
server.login(sender,password)
server.sendmail(sender, rec , message)
print("Mail Send Successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 5
#       3 from email.mime.text import MIMEText
#       4 from email.mime.multipart import MIMEMultipart
# ----> 5 from pretty_html_table import build_table
#       6 from email.message import EmailMessage
#       9 sender="nareshsisodiya1996@gmail.com"
#
# ModuleNotFoundError: No module named 'pretty_html_table'

# %%
sender="nareshsisodiya1996@gmail.com"
rec="naresh_kumar@sattrixsoftware.com"
password='yszbenixyrdrioei'
subject="Python"

conn=pymysql.connect(host="192.168.21.95", user="test", password="Sattrix@123", database="Trainings")
d=pd.read_sql("select * from SMPT",conn)
d=pd.DataFrame(d)
# d=build_table(d,"blue_light")

msg=EmailMessage()
msg['From']=sender
msg['To']=rec

msg['Subject']=subject
email_body='''\t hy this is data table for Logs {} Thanks And Regard Naresh Kumar'''.format(build_table(d,'blue_light'))
msg.set_content(email_body, subtype="html")
 
server=SMTP("smtp.gmail.com",587)
server.starttls()
server.login(sender,password)

server.send_message(msg)
# Out:
# /tmp/ipykernel_35252/4193370920.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   d=pd.read_sql("select * from SMPT",conn)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 15
#      13 msg['To']=rec
#      14 msg['Subject']=subject
# ---> 15 email_body='''\t hy this is data table for Logs {} Thanks And Regard Naresh Kumar'''.format(build_table(d,'blue_light'))
#      16 msg.set_content(email_body, subtype="html")
#      18 server=SMTP("smtp.gmail.com",587)
#
# NameError: name 'build_table' is not defined

# %%
report_id=123
report_name="chart and table"
report_notification=1
customerName="SATTRIX"
# save_location="C:/Users/Admin/Pictures/IMG_20230415_125432256.jpg"

# %%
import smtplib  
import mimetypes
import os
import requests
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
def report_notification_alert(report_id, report_name, report_notification,customerName,save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'smtp.office365.com'
            EmailConfigPort = 587
            EmailFromId = 'support@sattrixsoftware.com'
            EmailPassword = 'NE#@$Sattrix!12'
            pdf_file_path=save_location
            emailto =["naresh_kumar@sattrixsoftware.com"]
            EmailSubject = 'Report_Alert'
            email = MIMEMultipart()

            email['From'] = EmailFromId
            email['To'] =','.join(emailto)
            email['Subject'] = EmailSubject
            Title="NE | "+report_name
            with open(pdf_file_path, 'rb') as f:
                pdf_content = f.read()

            mime_type, encoding = mimetypes.guess_type(pdf_file_path)
            print(mime_type)
            if mime_type is None:
                mime_type = 'application/octet-stream'

            if pdf_file_path.endswith(".pdf"):

                attachment = MIMEBase(mime_type, 'pdf', filename=os.path.basename(pdf_file_path))

            elif pdf_file_path.endswith(".xlsx") or pdf_file_path.endswith('xls'):

                attachment = MIMEBase(mime_type, 'xlsx', filename=os.path.basename(pdf_file_path))

            else:

                attachment = MIMEBase(mime_type, 'csv', filename=os.path.basename(pdf_file_path))
            attachment.set_payload(pdf_content)
            encoders.encode_base64(attachment)
            email.attach(attachment)
            EmailTypeDescr = "Report Generated Successfully For Report Name {}  \nThank You".format(report_name)


 

#             email.attach(MIMEText(Title))

#             email.attach(MIMEText(EmailTypeDescr))

            html = """\
                    <html>
                    <head><title>NE</title></head>
                    <style>
                        .vl {
                          border-left: 6px solid green;
                          height: 10px;
                        }
                        .div{
                            height:100%;
                            width:100%
                        }
                        .div1{
                            float:left;
                            width:10%;
                            height:100%;
                        }
                        .div2{
                            float:left;
                            color:blue;
                            width:30%;
                            height:80%;
                        }
                        </style>
                      <body>
                        <p>Here is an example </p>
                        <div class=div>
                        <div class=div1><img  width=100px src="cid:image1"></div>
                        <div class=div2><a>sattrix@gmail.com</a></div>
                        </div>
                      </body>
                    </html>
                    """
            email.attach(MIMEText(html, 'html'))
            with open('/opt/NewEvol/Current/NewEvol_Solr/Datalake/reports/defualt_logo.png', 'rb') as f1:
                img_data = f1.read()
            image = MIMEImage(img_data)
            image.add_header('Content-ID', '<image1>')
            email.attach(image)
            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            mailserver.login(EmailFromId, EmailPassword)
            mailserver.sendmail(EmailFromId, emailto, email.as_string())
            mailserver.close()
        except smtplib.SMTPDataError as e:
            print("error while sending email: {}".format(e))
    if report_notification == 2:
        dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name,"customerName":customerName[1:-1]}
        url = 'https://192.168.21.198:8082/api/rulereport'
        response = requests.post(url, json=dict3,verify=False)
        
report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
# Out:
# image/jpeg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 112>()
#     109         url = 'https://192.168.21.198:8082/api/rulereport'
#     110         response = requests.post(url, json=dict3,verify=False)
# --> 112 report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
#
# Input In [11], in report_notification_alert(report_id, report_name, report_notification, customerName, save_location)
#      59 html = """\
#      60         <html>
#      61         <head><title>NE</title></head>
#    (...)
#      90         </html>
#      91         """
#      92 email.attach(MIMEText(html, 'html'))
# ---> 93 with open('/opt/NewEvol/Current/NewEvol_Solr/Datalake/reports/defualt_logo.png', 'rb') as f1:
#      94     img_data = f1.read()
#      95 image = MIMEImage(img_data)
#
# ...

# %%
# Out:
# application/pdf

# %%
<style>
.vl {
  border-left: 6px solid green;
  height: 500px;
}
</style>

<div class="vl"></div>

# %%
import smtplib  
import mimetypes
import os
import requests
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
def report_notification_alert(report_id, report_name, report_notification,customerName,save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'smtp.office365.com'
            EmailConfigPort = 587
            EmailFromId = 'support@sattrixsoftware.com'
            EmailPassword = 'NE#@$Sattrix!12'
            pdf_file_path=save_location
            emailto =["naresh_kumar@sattrixsoftware.com"]
            EmailSubject ="NE Report | "+report_name
            email = MIMEMultipart()

            email['From'] = EmailFromId
            email['To'] =','.join(emailto)
            email['Subject'] = EmailSubject
            Title="NE | "+report_name
            with open(save_location, 'rb') as f:
                pdf_content = f.read()

            mime_type, encoding = mimetypes.guess_type(pdf_file_path)
            print(mime_type)
            if mime_type is None:
                mime_type = 'application/octet-stream'

            if pdf_file_path.endswith(".pdf"):

                attachment = MIMEBase(mime_type, 'pdf', filename=os.path.basename(pdf_file_path))

            elif pdf_file_path.endswith(".xlsx") or pdf_file_path.endswith('xls'):

                attachment = MIMEBase(mime_type, 'xlsx', filename=os.path.basename(pdf_file_path))

            else:

                attachment = MIMEBase(mime_type, 'csv', filename=os.path.basename(pdf_file_path))
            attachment.set_payload(pdf_content)
            encoders.encode_base64(attachment)
            email.attach(attachment)
            EmailTypeDescr = "Report Generated Successfully For Report Name {}  \nThank You".format(report_name)


 

#             email.attach(MIMEText(Title))

#             email.attach(MIMEText(EmailTypeDescr))

            html = """\
                   <html>
                      <head><title>NE</title></head>
                      <style>
                        .vl {
                          border-left: 3px solid #DF511E;
                          float:left;
                          height: 100px;
                          margin:0px 10px;
                        }
                        .div{
                          display:block;
                          height:100%;
                          width:100%
                        }
                        .div1{
                          float:left;
                          width:15%;
                          height:100%;
                        }
                        .div2{
                          float:left;
                          color:blue;
                          width:40%;
                          height:100%;
                          text-align:center;
                        }
                      </style>
                      <body>
                        <p>Here is an example </p>
                        <div class=div>
                          <div class=div1><img  width=100px src=""></div>
                          <div class="vl"></div>
                          <div class=div2>
                            <a href="https://outlook.office.com/mail/inbox/id/AAQkADZlNGQxMzAyLWRhMjEtNGRlZS1hMjVhLWMxNjY1N2NjNjQzMwAQAK4bb%2Fjdh0%2FendGgHQAxkrk%3D">support@sattrixsoftware.com</a><br>
                          </div>
                          <div class="vl"></div>
                          <div class=div1><img  width=100px src=""></div>
                        </div>
                      </body>
                    </html>
                    """
            email.attach(MIMEText(html, 'html'))
            with open(save_location, 'rb') as f1:
                img_data = f1.read()
            image = MIMEImage(img_data)
            image.add_header('Content-ID', '<image1>')
            email.attach(image)
            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            mailserver.login(EmailFromId, EmailPassword)
            mailserver.sendmail(EmailFromId, emailto, email.as_string())
            mailserver.close()
        except smtplib.SMTPDataError as e:
            print("error while sending email: {}".format(e))
    if report_notification == 2:
        dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name,"customerName":customerName[1:-1]}
        url = 'https://192.168.21.198:8082/api/rulereport'
        response = requests.post(url, json=dict3,verify=False)
        
report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
# Out:
# image/jpeg

# %%
import smtplib

sender="nareshsisodiya1996@gmail.com"
rec="naresh_kumar@sattrixsoftware.com"
password='yszbenixyrdrioei'

# sender = 'from@fromdomain.com'
receivers = ['naresh_kumar@sattrixsoftware.com']

message = """From: From Person <from@fromdomain.com>
To: To Person <to@todomain.com>
Subject: SMTP e-mail test

This is a test e-mail message.
"""


smtpObj = smtplib.SMTP(587)
smtpObj.sendmail(sender, receivers, message)         
print("Successfully sent email")
# except Exception as err:
#     print("Error: unable to send email")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [28], in <cell line: 18>()
#       8 receivers = ['naresh_kumar@sattrixsoftware.com']
#      10 message = """From: From Person <from@fromdomain.com>
#      11 To: To Person <to@todomain.com>
#      12 Subject: SMTP e-mail test
#      13
#      14 This is a test e-mail message.
#      15 """
# ---> 18 smtpObj = smtplib.SMTP(587)
#      19 smtpObj.sendmail(sender, receivers, message)
#      20 print("Successfully sent email")
#
# File ~\anaconda3\lib\smtplib.py:255, in SMTP.__init__(self, host, port, local_hostname, timeout, source_address)
#     252 self._auth_challenge_count = 0
#     254 if host:
# --> 255     (code, msg) = self.connect(host, port)
#     256     if code != 220:
#     257         self.close()
#
# File ~\anaconda3\lib\smtplib.py:330, in SMTP.connect(self, host, port, source_address)
# ...

# %%
<html>

<head>
    <title>NE</title>
</head>
<style>
    .vl {
        border-left: 3px solid #DF511E;
        float: left;
        height: 100px;
        margin: 0px 10px;
    }
    .img {
        width:30px;
    }

    .div {
        height: 20%;
        width: 100%
    }

    .div1 {
        float: left;
        width: 30%;
        height: 100%;
    }

    .div2 {
        float: left;
        color: blue;
        width: 35%;
        height: 100%;
        /* display: block; */
        text-align: center;
        margin-top: 30px;
        margin-bottom: 30px;
        
    }
    .div3{
        float: right;
        width: 30%;
        height: 100%;
        margin: 15px 10px;
    }
</style>

<body>
    <p>Here is an example </p>
    <div class=div>
        <div class=div1><img width=70px src="C:\Users\Admin\Downloads\thumbnail_image002.png"></div>
        <div class="vl"></div>
        <div class=div2>
            <a href="https://outlook.office.com/mail/inbox/id/AAQkADZlNGQxMzAyLWRhMjEtNGRlZS1hMjVhLWMxNjY1N2NjNjQzMwAQAK4bb%2Fjdh0%2FendGgHQAxkrk%3D">support@sattrixsoftware.com</a><br>
            <a href="https://twitter.com/i/flow/login?redirect_after_login=%2FSattrixSoftware"> <img class="img" src="twitter.png" alt=""></a>
            <a href="https://www.linkedin.com/company/sattrix-software-solutions/"> <img class="img" src="linkdin.webp" alt=""></a>
            
        </div>
        <div class="vl"></div>
        <div class=div3><img width=100px src="thumbnail_image005.png"></div>
    </div>
</body>

</html>
# Out:
#   Input In [31]
#     <html>
#     ^
# SyntaxError: invalid syntax

# %%
import smtplib  
import mimetypes
import os
import requests
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
def report_notification_alert(report_id, report_name, report_notification,customerName,save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'smtp.office365.com'
            EmailConfigPort = 587
            EmailFromId = 'support@sattrixsoftware.com'
            EmailPassword = 'NE#@$Sattrix!12'
            pdf_file_path=save_location
            emailto =["naresh_kumar@sattrixsoftware.com"]
            EmailSubject ="NE Report | "+report_name
            email = MIMEMultipart()

            email['From'] = EmailFromId
            email['To'] =','.join(emailto)
            email['Subject'] = EmailSubject
            Title="NE | "+report_name
            with open(pdf_file_path, 'rb') as f:
                pdf_content = f.read()

            mime_type, encoding = mimetypes.guess_type(pdf_file_path)
            print(mime_type)
            if mime_type is None:
                mime_type = 'application/octet-stream'

            if pdf_file_path.endswith(".pdf"):

                attachment = MIMEBase(mime_type, 'pdf', filename=os.path.basename(pdf_file_path))

            elif pdf_file_path.endswith(".xlsx") or pdf_file_path.endswith('xls'):

                attachment = MIMEBase(mime_type, 'xlsx', filename=os.path.basename(pdf_file_path))

            else:

                attachment = MIMEBase(mime_type, 'csv', filename=os.path.basename(pdf_file_path))
            attachment.set_payload(pdf_content)
            encoders.encode_base64(attachment)
            email.attach(attachment)
            EmailTypeDescr = "Report Generated Successfully For Report Name {}  \nThank You".format(report_name)


 

#             email.attach(MIMEText(Title))

#             email.attach(MIMEText(EmailTypeDescr))

            html = """\
                       <html>

                            <head>
                                <title>NE</title>
                            </head>
                            <style>
                                .vl {
                                    border-left: 3px solid #DF511E;
                                    float: left;
                                    height: 100px;
                                    margin: 0px 10px;
                                }
                                .img {
                                    width:30px;
                                }

                                .div {
                                    height: 20%;
                                    width: 100%
                                }

                                .div1 {
                                    float: left;
                                    width: 30%;
                                    height: 100%;
                                }

                                .div2 {
                                    float: left;
                                    color: blue;
                                    width: 35%;
                                    height: 100%;
                                    /* display: block; */
                                    text-align: center;
                                    margin-top: 30px;
                                    margin-bottom: 30px;

                                }
                                .div3{
                                    float: right;
                                    width: 30%;
                                    height: 100%;
                                    margin: 15px 10px;
                                }
                            </style>

                            <body>
                                <p>Here is an example </p>
                                <div class=div>
                                    <div class=div1><img width=70px src="C:/Users/Admin/Downloads/thumbnail_image002.png"></div>
                                    <div class="vl"></div>
                                    <div class=div2>
                                        <a href="https://outlook.office.com/mail/inbox/id/AAQkADZlNGQxMzAyLWRhMjEtNGRlZS1hMjVhLWMxNjY1N2NjNjQzMwAQAK4bb%2Fjdh0%2FendGgHQAxkrk%3D">support@sattrixsoftware.com</a><br>
                                        <a href="https://twitter.com/i/flow/login?redirect_after_login=%2FSattrixSoftware"> <img class="img" src="twitter.png" alt=""></a>
                                        <a href="https://www.linkedin.com/company/sattrix-software-solutions/"> <img class="img" src="linkdin.webp" alt=""></a>

                                    </div>
                                    <div class="vl"></div>
                                    <div class=div3><img width=100px src="C:/Users/Admin/Downloads/thumbnail_image005.png"></div>
                                </div>
                            </body>
                            </html>
                            """
            email.attach(MIMEText(html, 'html'))
#             with open( "C:/Users/Admin/Downloads/thumbnail_image005.png", 'rb') as f1:
#                 img_data = f1.read()
#             image = MIMEImage(img_data)
#             image.add_header('Content-ID', '<image1>')
#             email.attach()
            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            mailserver.login(EmailFromId, EmailPassword)
            mailserver.sendmail(EmailFromId, emailto, email.as_string())
            mailserver.close()
        except smtplib.SMTPDataError as e:
            print("error while sending email: {}".format(e))
    if report_notification == 2:
        dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name,"customerName":customerName[1:-1]}
        url = 'https://192.168.21.198:8082/api/rulereport'
        response = requests.post(url, json=dict3,verify=False)
        
report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
# Out:
# image/jpeg

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.application import MIMEApplication
EmailConfigHost='smtp.office365.com'

EmailConfigPort = '587'  # Use the appropriate port for your SMTP server
smtp_server = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
smtp_username ='support@sattrixsoftware.com'
smtp_password ='NE#@$Sattrix!12'


sender_email ='support@sattrixsoftware.com'
recipient_email = 'naresh_kumar@sattrixsoftware.com'
msg = MIMEMultipart()
msg['From'] = sender_email
msg['To'] = recipient_email
msg['Subject'] = report_name
email_body = """
Hello,

This is the body of your email.

Company Email: 'support@sattrixsoftware.com'

Below is our company logo:
"""

msg.attach(MIMEText(email_body, 'plain'))

with open('C:/Users/Admin/Downloads/thumbnail_image002.png', 'rb') as logo_file:
    logo = MIMEImage(logo_file.read())
    logo.add_header('Content-Disposition', 'attachment', filename='company_logo.png')
    msg.attach(logo)
with open('C:/Users/Admin/Downloads/thumbnail_image002.png', 'rb') as logo_file:
    logo = MIMEImage(logo_file.read())
    logo.add_header('Content-Disposition', 'attachment', filename='company_logo.png')
    msg.attach(logo)
# try:
    server = smtplib.SMTP(smtp_server, EmailConfigPort)
    server.starttls()
    server.login(smtp_username, smtp_password)
    server.sendmail(sender_email, recipient_email, msg.as_string())
    server.quit()
    print("Email sent successfully!")
# except Exception as e:
    print(f"Error: {str(e)}")

# %%
report_id=123
report_name="chart and table"
report_notification=1
customerName="SATTRIX"
save_location="C:/Users/Admin/Downloads/Python Lectureflow.pdf"

# %%
import smtplib  
import mimetypes
import os
import requests
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
def report_notification_alert(report_id, report_name, report_notification,customerName,save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'smtp.office365.com'
            EmailConfigPort = 587
            EmailFromId = 'support@sattrixsoftware.com'
            EmailPassword = 'NE#@$Sattrix!12'
            pdf_file_path=save_location
            emailto =["naresh_kumar@sattrixsoftware.com"]
            EmailSubject = 'Ne Report |'+report_name
            email = MIMEMultipart()
            email['From'] = EmailFromId
            email['To'] =','.join(emailto)
            email['Subject'] = EmailSubject
            Title="NE | "+report_name
            with open(pdf_file_path, 'rb') as f:
                pdf_content = f.read()
            mime_type, encoding = mimetypes.guess_type(pdf_file_path)
            print(mime_type)
            if mime_type is None:
                mime_type = 'application/octet-stream'
            if pdf_file_path.endswith(".pdf"):
                attachment = MIMEBase(mime_type, 'pdf', filename=os.path.basename(pdf_file_path))
            elif pdf_file_path.endswith(".xlsx") or pdf_file_path.endswith('xls'):
                attachment = MIMEBase(mime_type, 'xlsx', filename=os.path.basename(pdf_file_path))
            else:
                attachment = MIMEBase(mime_type, 'csv', filename=os.path.basename(pdf_file_path))
            attachment.set_payload(pdf_content)
            encoders.encode_base64(attachment)
            email.attach(attachment)
            EmailTypeDescr = "Report Generated Successfully For Report Name {}  \nThank You".format(report_name)
#             email.attach(MIMEText(Title))
#             email.attach(MIMEText(EmailTypeDescr))
            html = """\
                     <html>

                            <head>
                                <title>NE</title>
                            </head>
                            <style>
                                .vl {
                                    border-left: 3px solid #DF511E;
                                    float: left;
                                    height: 100px;
                                    margin: 0px 5px;
                                }
                                .img {
                                    width:10%;
                                    margin:5px;
                                }

                                .div {
                                    display:block;
                                    height:100%;
                                    width:100%;
                                }

                                .div1 {
                                    float: left;
                                    width: 20%;
                                    height: 80%;
                                }

                                .div2 {
                                    float: left;
                                    color: blue;
                                    width: 40%;
                                    height: 100%;
                                    text-align: center;
                                    margin-top: 30px;
                                    margin-bottom: 30px;

                                }
                                .div3{
                                    float: left;
                                    width: 25%;
                                    height: 100%;
                                    margin: 15px 10px;
                                }
                                .img2{
                                    height:60%;
                                    width:auto;
                                }
                            </style>

                            <body>
                                <p>Here is an example </p>
                                <div class=div>
                                    <div class=div1><img class=img2 src=cid:image1></div>
                                    <div class="vl"></div>
                                    <div class=div2>
                                        <a href="https://outlook.office.com/mail/inbox/id/AAQkADZlNGQxMzAyLWRhMjEtNGRlZS1hMjVhLWMxNjY1N2NjNjQzMwAQAK4bb%2Fjdh0%2FendGgHQAxkrk%3D">support@sattrixsoftware.com</a><br>
                                        <a href="https://twitter.com/i/flow/login?redirect_after_login=%2FSattrixSoftware"> <img class="img" src=cid:image3 alt="image not found"></a>
                                        <a href="https://www.linkedin.com/company/sattrix-software-solutions/"> <img class="img" src=cid:image4 alt="image not found"></a>

                                    </div>
                                    <div class="vl"></div>
                                    <div class=div3><img width=80% src=cid:image2></div>
                                </div><br>
                            </body>
                            </html>
                    """
            email.attach(MIMEText(html, 'html'))
            with open("C:/Users/Admin/Downloads/thumbnail_image002.jpg", 'rb') as f1:
                img_data = f1.read()
            image = MIMEImage(img_data)
            email.attach(image)
            image.add_header('Content-ID', '<image1>')
            with open("C:/Users/Admin/Downloads/thumbnail_image005.png", 'rb') as f1:
                img_data2 = f1.read()
            image = MIMEImage(img_data2)
            image.add_header('Content-ID', '<image2>')
            email.attach(image)
            with open("C:/Users/Admin/Downloads/twitter.png", 'rb') as f1:
                img_data3 = f1.read()
            image = MIMEImage(img_data3)
            image.add_header('Content-ID', '<image3>')
            email.attach(image)
            with open("C:/Users/Admin/Downloads/linkdin.webp", 'rb') as f1: 
                img_data4= f1.read()
            image = MIMEImage(img_data4)
            image.add_header('Content-ID', '<image4>')
            email.attach(image)
            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            mailserver.login(EmailFromId, EmailPassword)
            mailserver.sendmail(EmailFromId, emailto, email.as_string())
            mailserver.close()
        except smtplib.SMTPDataError as e:
            print("error while sending email: {}".format(e))
    if report_notification == 2:
        dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name,"customerName":customerName[1:-1]}
        url = 'https://192.168.21.198:8082/api/rulereport'
        response = requests.post(url, json=dict3,verify=False)
report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
# Out:
# application/pdf

# %%
import smtplib  
import mimetypes
import os
import requests
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
def report_notification_alert(report_id, report_name, report_notification,customerName,save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'smtp.office365.com'
            EmailConfigPort = 587
            EmailFromId = 'support@sattrixsoftware.com'
            EmailPassword = 'NE#@$Sattrix!12'
            pdf_file_path=save_location
            emailto =["naresh_kumar@sattrixsoftware.com"]
            EmailSubject = 'Ne Report |'+report_name
            email = MIMEMultipart()
            email['From'] = EmailFromId
            email['To'] =','.join(emailto)
            email['Subject'] = EmailSubject
            Title="NE | "+report_name
            with open(pdf_file_path, 'rb') as f:
                pdf_content = f.read()
            mime_type, encoding = mimetypes.guess_type(pdf_file_path)
            print(mime_type)
            if mime_type is None:
                mime_type = 'application/octet-stream'
            if pdf_file_path.endswith(".pdf"):
                attachment = MIMEBase(mime_type, 'pdf', filename=os.path.basename(pdf_file_path))
            elif pdf_file_path.endswith(".xlsx") or pdf_file_path.endswith('xls'):
                attachment = MIMEBase(mime_type, 'xlsx', filename=os.path.basename(pdf_file_path))
            else:
                attachment = MIMEBase(mime_type, 'csv', filename=os.path.basename(pdf_file_path))
            attachment.set_payload(pdf_content)
            encoders.encode_base64(attachment)
            email.attach(attachment)
            EmailTypeDescr = "Report Generated Successfully For Report Name {}  \nThank You".format(report_name)
#             email.attach(MIMEText(Title))
#             email.attach(MIMEText(EmailTypeDescr))
            html = """\
                     <html>

                            <head>
                                <title>NE</title>
                            </head>
                            <style>
                                .vl {
                                    border-left: 3px solid #DF511E;
                                    float: left;
                                    height: 100px;
                                    margin: 0px 5px;
                                }
                                .img {
                                    width:10%;
                                    margin:5px;
                                }

                                .div {
                                    display:block;
                                    height:100%;
                                    width:100%;
                                }

                                .div1 {
                                    float: left;
                                    width: 20%;
                                    height: 80%;
                                }

                                .div2 {
                                    float: left;
                                    color: blue;
                                    width: 40%;
                                    height: 100%;
                                    text-align: center;
                                    margin-top: 30px;
                                    margin-bottom: 30px;

                                }
                                .div3{
                                    float: left;
                                    width: 25%;
                                    height: 100%;
                                    margin: 15px 10px;
                                }
                                .img2{
                                    height:60%;
                                    width:auto;
                                }
                            </style>

                            <body>
                                <p>Here is an example </p>
                                <div class=div>
                                    <div class=div1><img class=img2 src="C:/Users/Admin/Downloads/thumbnail_image002.jpg"></div>
                                    <div class="vl"></div>
                                    <div class=div2>
                                        <a href="https://outlook.office.com/mail/inbox/id/AAQkADZlNGQxMzAyLWRhMjEtNGRlZS1hMjVhLWMxNjY1N2NjNjQzMwAQAK4bb%2Fjdh0%2FendGgHQAxkrk%3D">support@sattrixsoftware.com</a><br>
                                        <a href="https://twitter.com/i/flow/login?redirect_after_login=%2FSattrixSoftware"> <img class="img" src="C:/Users/Admin/Downloads/twitter.png" alt="image not found"></a>
                                        <a href="https://www.linkedin.com/company/sattrix-software-solutions/"> <img class="img" src="C:/Users/Admin/Downloads/linkdin.webp" alt="image not found"></a>

                                    </div>
                                    <div class="vl"></div>
                                    <div class=div3><img width=80% src="C:/Users/Admin/Downloads/thumbnail_image005.png"></div>
                                </div><br>
                            </body>
                            </html>
                    """
            binary_data = html.encode('utf-8')
            binary_string = ''.join(format(byte, '08b') for byte in binary_data)
            email.attach(MIMEText(html, 'binary_string'))
#             with open("C:/Users/Admin/Downloads/thumbnail_image002.jpg", 'rb') as f1:
#                 img_data = f1.read()
#             image = MIMEImage(img_data)
#             email.attach(image)
#             image.add_header('Content-ID', '<image1>')
#             with open("C:/Users/Admin/Downloads/thumbnail_image005.png", 'rb') as f1:
#                 img_data2 = f1.read()
#             image = MIMEImage(img_data2)
#             image.add_header('Content-ID', '<image2>')
#             email.attach(image)
#             with open("C:/Users/Admin/Downloads/twitter.png", 'rb') as f1:
#                 img_data3 = f1.read()
#             image = MIMEImage(img_data3)
#             image.add_header('Content-ID', '<image3>')
#             email.attach(image)
#             with open("C:/Users/Admin/Downloads/linkdin.webp", 'rb') as f1: 
#                 img_data4= f1.read()
#             image = MIMEImage(img_data4)
#             image.add_header('Content-ID', '<image4>')
#             email.attach(image)
            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            mailserver.login(EmailFromId, EmailPassword)
            mailserver.sendmail(EmailFromId, emailto, email.as_string())
            mailserver.close()
        except smtplib.SMTPDataError as e:
            print("error while sending email: {}".format(e))
    if report_notification == 2:
        dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name,"customerName":customerName[1:-1]}
        url = 'https://192.168.21.198:8082/api/rulereport'
        response = requests.post(url, json=dict3,verify=False)
report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
# Out:
# application/pdf

# %%
import smtplib
import os
import requests
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

def report_notification_alert(report_id, report_name, report_notification, customerName, save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'smtp.office365.com'
            EmailConfigPort = 587
            EmailFromId = 'support@sattrixsoftware.com'
            EmailPassword = 'NE#@$Sattrix!12'
            pdf_file_path = save_location
            emailto = ["naresh_kumar@sattrixsoftware.com"]
            EmailSubject = 'NE Report | ' + report_name
            email = MIMEMultipart()
            email['From'] = EmailFromId
            email['To'] = ','.join(emailto)
            email['Subject'] = EmailSubject

            # Attach the PDF file
            with open(pdf_file_path, 'rb') as f:
                attachment = MIMEBase('application', 'octet-stream')
                attachment.set_payload(f.read())
                encoders.encode_base64(attachment)
                attachment.add_header('Content-Disposition', f'attachment; filename={os.path.basename(pdf_file_path)}')
                email.attach(attachment)

            # HTML content
            html = """
                <html>
                <body>
                    <p>Here is an example:</p>
                    <img src="cid:image1" width="100">
                    <a href="https://outlook.office.com/mail/inbox/id/AAQkADZlNGQxMzAyLWRhMjEtNGRlZS1hMjVhLWMxNjY1N2NjNjQzMwAQAK4bb%2Fjdh0%2FendGgHQAxkrk%3D">support@sattrixsoftware.com</a><br>
                    <a href="https://twitter.com/i/flow/login?redirect_after_login=%2FSattrixSoftware"><img src="cid:image2" width="100" alt="Twitter"></a>
                    <a href="https://www.linkedin.com/company/sattrix-software-solutions/"><img src="cid:image3" width="100" alt="LinkedIn"></a>
                </body>
                </html>
                """

            # Attach embedded images
            for image_path, cid in [("C:/Users/Admin/Downloads/thumbnail_image002.jpg", "image1"),
                                    ("C:/Users/Admin/Downloads/twitter.png", "image2"),
                                    ("C:/Users/Admin/Downloads/linkdin.webp", "image3")]:
                with open(image_path, 'rb') as img_file:
                    image = MIMEBase('application', 'octet-stream')
                    image.set_payload(img_file.read())
                    encoders.encode_base64(image)
                    image.add_header('Content-ID', f'<{cid}>')
                    email.attach(image)

            email.attach(MIMEText(html, 'html'))

            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            mailserver.login(EmailFromId, EmailPassword)
            mailserver.sendmail(EmailFromId, emailto, email.as_string())
            mailserver.close()
        except Exception as e:
            print(f"Error while sending email: {e}")

    if report_notification == 2:
        dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name, "customerName": customerName[1:-1]}
        url = 'https://192.168.21.198:8082/api/rulereport'
        response = requests.post(url, json=dict3, verify=False)



report_notification_alert(report_id, report_name, report_notification, customerName, save_location)

# %%
report_id=123
report_name="chart and table"
report_notification=1
customerName="SATTRIX"
save_location="C:/Users/Admin/Downloads/Python Lectureflow.pdf"

# %%
import smtplib
import os
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.image import MIMEImage
from email.mime.application import MIMEApplication
from email import encoders

def send_email_with_attachment_and_images():
    try:
        # SMTP Configuration
        smtp_server = 'smtp.office365.com'
        smtp_port = 587
        smtp_username ='support@sattrixsoftware.com'
        smtp_password =  'NE#@$Sattrix!12'
#         EmailFromId = 'support@sattrixsoftware.com'
#             EmailPassword = 'NE#@$Sattrix!12'
        # Email Content
        sender_email = 'support@sattrixsoftware.com'
        recipient_email = 'naresh_kumar@sattrixsoftware.com'
        email_subject = 'Email Subject'

        # Create an email message
        email = MIMEMultipart()
        email['From'] = sender_email
        email['To'] = recipient_email
        email['Subject'] = email_subject

        # Attach PDF
        pdf_file_path ="C:/Users/Admin/Downloads/Python Lectureflow.pdf"
        with open(pdf_file_path, 'rb') as pdf_file:
            attachment = MIMEApplication(pdf_file.read())
            attachment.add_header('Content-Disposition', 'attachment', filename=os.path.basename(pdf_file_path))
            email.attach(attachment)

        # HTML Content with Logo and Image
        html = """
            <html>
            <body>
                <p>Here is your email body.</p>
                <img src="cid:logo_image" width="200">
                <img src="cid:other_image" width="200">
            </body>
            </html>
        """

        email.attach(MIMEText(html, 'html'))

        # Attach Logo Image
        logo_image_path = "C:/Users/Admin/Downloads/thumbnail_image002.jpg"
        with open(logo_image_path, 'rb') as logo_image_file:
            logo_image = MIMEImage(logo_image_file.read())
            logo_image.add_header('Content-ID', '<logo_image>')
            email.attach(logo_image)

        # Attach Another Image
        other_image_path = "C:/Users/Admin/Downloads/twitter.png"
        with open(other_image_path, 'rb') as other_image_file:
            other_image = MIMEImage(other_image_file.read())
            other_image.add_header('Content-ID', '<other_image>')
            email.attach(other_image)

        # Connect to SMTP server and send email
        server = smtplib.SMTP(smtp_server, smtp_port)
        server.starttls()
        server.login(smtp_username, smtp_password)
        server.sendmail(sender_email, recipient_email, email.as_string())
        server.quit()

        print("Email sent successfully!")

    except Exception as e:
        print(f"Error: {str(e)}")

# Call the function to send the email
send_email_with_attachment_and_images()
# Out:
# Email sent successfully!

# %%
import smtplib  
import mimetypes
import os
import requests
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
def report_notification_alert(report_id, report_name, report_notification,customerName,save_location):
    if report_notification == 1:
        try:
            EmailConfigHost = 'smtp.office365.com'
            EmailConfigPort = 587
            EmailFromId = 'support@sattrixsoftware.com'
            EmailPassword = 'NE#@$Sattrix!12'
            pdf_file_path=save_location
            emailto =["naresh_kumar@sattrixsoftware.com","atul_kumar@sattrixsoftware.com"]
            EmailSubject = 'Ne Report |'+report_name
            email = MIMEMultipart()
            email['From'] = EmailFromId
            email['To'] =','.join(emailto)
            email['Subject'] = EmailSubject
            Title="NE | "+report_name
            with open(pdf_file_path, 'rb') as f:
                pdf_content = f.read()
            mime_type, encoding = mimetypes.guess_type(pdf_file_path)
            print(mime_type)
            if mime_type is None:
                mime_type = 'application/octet-stream'
            if pdf_file_path.endswith(".pdf"):
                attachment = MIMEBase(mime_type, 'pdf', filename=os.path.basename(pdf_file_path))
            elif pdf_file_path.endswith(".xlsx") or pdf_file_path.endswith('xls'):
                attachment = MIMEBase(mime_type, 'xlsx', filename=os.path.basename(pdf_file_path))
            else:
                attachment = MIMEBase(mime_type, 'csv', filename=os.path.basename(pdf_file_path))
            attachment.set_payload(pdf_content)
            encoders.encode_base64(attachment)
            email.attach(attachment)
            EmailTypeDescr = "Report Generated Successfully For Report Name {}  \nThank You".format(report_name)
#             email.attach(MIMEText(Title))
#             email.attach(MIMEText(EmailTypeDescr))
            html = """\
                     <html>

                            <head>
                                <title>NE</title>
                            </head>
                            <style>
                                .vl {
                                    border-left: 3px solid #DF511E;
                                    float: left;
                                    height: 100px;
                                    margin: 0px 5px;
                                }
                                .img {
                                    width:10%;
                                    margin:5px;
                                }

                                .div {
                                    display:block;
                                    height:100%;
                                    width:100%;
                                }

                                .div1 {
                                    float: left;
                                    width: 20%;
                                    height: 80%;
                                }

                                .div2 {
                                    float: left;
                                    color: blue;
                                    width: 40%;
                                    height: 100%;
                                    text-align: center;
                                    margin-top: 30px;
                                    margin-bottom: 30px;

                                }
                                .div3{
                                    float: left;
                                    width: 25%;
                                    height: 100%;
                                    margin: 15px 10px;
                                }
                                .img2{
                                    height:60%;
                                    width:auto;
                                }
                            </style>

                            <body>
                                <p>Here is an example </p>
                                <div class=div>
                                    <div class=div1><img class=img2 src=cid:image1></div>
                                    <div class="vl"></div>
                                    <div class=div2>
                                        <a href="https://outlook.office.com/mail/inbox/id/AAQkADZlNGQxMzAyLWRhMjEtNGRlZS1hMjVhLWMxNjY1N2NjNjQzMwAQAK4bb%2Fjdh0%2FendGgHQAxkrk%3D">support@sattrixsoftware.com</a><br>
                                        <a href="https://twitter.com/i/flow/login?redirect_after_login=%2FSattrixSoftware"> <img class="img" src=cid:image3 alt="image not found"></a>
                                        <a href="https://www.linkedin.com/company/sattrix-software-solutions/"> <img class="img" src=cid:image4 alt="image not found"></a>

                                    </div>
                                    <div class="vl"></div>
                                    <div class=div3><img width=80% src=cid:image2></div>
                                </div><br>
                            </body>
                            </html>
                    """
            email.attach(MIMEText(html, 'html'))
            with open("C:/Users/Admin/Downloads/thumbnail_image002.jpg", 'rb') as f1:
                img_data = f1.read()
            image = MIMEImage(img_data)
            email.attach(image)
            image.add_header('Content-ID', '<image1>')
            with open("C:/Users/Admin/Downloads/thumbnail_image005.png", 'rb') as f1:
                img_data2 = f1.read()
            image = MIMEImage(img_data2)
            image.add_header('Content-ID', '<image2>')
            email.attach(image)
            with open("C:/Users/Admin/Downloads/twitter.png", 'rb') as f1:
                img_data3 = f1.read()
            image = MIMEImage(img_data3)
            image.add_header('Content-ID', '<image3>')
            email.attach(image)
            with open("C:/Users/Admin/Downloads/linkdin.webp", 'rb') as f1: 
                img_data4= f1.read()
            image = MIMEImage(img_data4)
            image.add_header('Content-ID', '<image4>')
            email.attach(image)
            mailserver = smtplib.SMTP(EmailConfigHost, EmailConfigPort)
            mailserver.ehlo()
            mailserver.starttls()
            mailserver.ehlo()
            mailserver.login(EmailFromId, EmailPassword)
            mailserver.sendmail(EmailFromId, emailto, email.as_string())
            mailserver.close()
        except smtplib.SMTPDataError as e:
            print("error while sending email: {}".format(e))
    if report_notification == 2:
        dict3 = {'Report_Id': str(report_id), 'Report_Name': report_name,"customerName":customerName[1:-1]}
        url = 'https://192.168.21.198:8082/api/rulereport'
        response = requests.post(url, json=dict3,verify=False)
report_notification_alert(report_id, report_name, report_notification,customerName,save_location)
# Out:
# application/pdf
